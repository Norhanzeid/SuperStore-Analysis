# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('Superstore.xlsx')
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 1          2  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 2          3  CA-2013-138688 2013-06-13 2013-06-17    Second Class
# 3          4  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 4          5  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2011-110422 2011-01-22 2011-01-24    Second Class
# 9990    9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9991    9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9992    9993  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9993    9994  CA-2014-119914 2014-05-05 2014-05-10    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.drop('Row ID',axis=1,inplace= True)

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2     CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2011-110422 2011-01-22 2011-01-24    Second Class    TB-21400
# 9990  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9993  CA-2014-119914 2014-05-05 2014-05-10    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df['Sales'].idxmax()
# Out:
# 2697

# %%
df.loc[2697]
# Out:
# Order ID                                            CA-2011-145317
# Order Date                                     2011-03-18 00:00:00
# Ship Date                                      2011-03-23 00:00:00
# Ship Mode                                           Standard Class
# Customer ID                                               SM-20320
# Customer Name                                          Sean Miller
# Segment                                                Home Office
# Country                                              United States
# City                                                  Jacksonville
# State                                                      Florida
# Postal Code                                                  32216
# Region                                                       South
# Product ID                                         TEC-MA-10002412
# Category                                                Technology
# ...

# %%
df['Profit'].idxmax()
# Out:
# 6826

# %%
df.loc[6826]
# Out:
# Order ID                                CA-2013-118689
# Order Date                         2013-10-03 00:00:00
# Ship Date                          2013-10-10 00:00:00
# Ship Mode                               Standard Class
# Customer ID                                   TC-20980
# Customer Name                             Tamara Chand
# Segment                                      Corporate
# Country                                  United States
# City                                         Lafayette
# State                                          Indiana
# Postal Code                                      47905
# Region                                         Central
# Product ID                             TEC-CO-10004722
# Category                                    Technology
# Sub-Category                                   Copiers
# Product Name     Canon imageCLASS 2200 Advanced Copier
# Sales                                         17499.95
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Length: 9994, dtype: bool

# %%
if df.duplicated().sum():
    print('duplication is found !')
else:
    print('no duplication is found!')
# Out:
# duplication is found !

# %%
duplicates=df.duplicated()
rows_with_duplicated=df[duplicates]
rows_with_duplicated
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3406  US-2011-150119 2011-04-23 2011-04-27  Standard Class    LB-16795
#
#        Customer Name      Segment        Country      City State  Postal Code  \
# 3406  Laurel Beltran  Home Office  United States  Columbus  Ohio        43229
#
#      Region       Product ID   Category Sub-Category  \
# 3406   East  FUR-CH-10002965  Furniture       Chairs
#
#                                            Product Name    Sales  Quantity  \
# 3406  Global Leather Highback Executive Chair with P...  281.372         2
#
#       Discount   Profit
# 3406       0.3 -12.0588

# %% [raw]
# #Feature engineering is the process of selecting, transforming
# or creating new features from the raw data to improve the performance of a machine learning model.
# Feature engineering aims to highlight important information and provide a more informative representation of the data.
#
# common techniques in feature engineering include:
#
# Feature Selection
# Feature Scaling
# One-Hot Encoding
# Polynomial Features

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2     CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2011-110422 2011-01-22 2011-01-24    Second Class    TB-21400
# 9990  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9993  CA-2014-119914 2014-05-05 2014-05-10    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df['total_discount']=df['Sales']*df['Discount']   # 100000*0.05=5000  ====> 95000

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2     CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2011-110422 2011-01-22 2011-01-24    Second Class    TB-21400
# 9990  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9993  CA-2014-119914 2014-05-05 2014-05-10    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df['Dicounted_sales']=df['Sales']-df['total_discount']

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2     CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2011-110422 2011-01-22 2011-01-24    Second Class    TB-21400
# 9990  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9993  CA-2014-119914 2014-05-05 2014-05-10    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df['selling_price']=df['Sales']/df['Quantity']

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2     CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2011-110422 2011-01-22 2011-01-24    Second Class    TB-21400
# 9990  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9993  CA-2014-119914 2014-05-05 2014-05-10    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df['net profit per unit sold']=df['Profit']/df['Quantity']

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2     CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2011-110422 2011-01-22 2011-01-24    Second Class    TB-21400
# 9990  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9993  CA-2014-119914 2014-05-05 2014-05-10    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df['order_delivery_time']=df['Ship Date']-df['Order Date']

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2     CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2011-110422 2011-01-22 2011-01-24    Second Class    TB-21400
# 9990  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9993  CA-2014-119914 2014-05-05 2014-05-10    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df['net profit before discount'] =df['Profit']+df['total_discount']

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2     CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2011-110422 2011-01-22 2011-01-24    Second Class    TB-21400
# 9990  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9993  CA-2014-119914 2014-05-05 2014-05-10    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2     CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2011-110422 2011-01-22 2011-01-24    Second Class    TB-21400
# 9990  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9993  CA-2014-119914 2014-05-05 2014-05-10    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %% [markdown]
# # ship mode

# %%
types_of_shipping=df['Ship Mode'].unique()

# %%
types_of_shipping
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
shipping_mode=df['Ship Mode'].value_counts().reset_index().rename(columns={'index':'ship_mode','Ship Mode':'Frequency'})
shipping_mode
# Out:
#         ship_mode  Frequency
# 0  Standard Class       5968
# 1    Second Class       1945
# 2     First Class       1538
# 3        Same Day        543

# %%
#pie chart
plt.pie(shipping_mode['Frequency'],labels=shipping_mode['ship_mode'],autopct='%1.1f%%')
plt.title('popular mode of shipment')
plt.show()

# %% [markdown]
# # Segment

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2     CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2011-110422 2011-01-22 2011-01-24    Second Class    TB-21400
# 9990  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9993  CA-2014-119914 2014-05-05 2014-05-10    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
types_of_customers =df['Segment'].unique()
types_of_customers
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
customer_segmentation=df['Segment'].value_counts().reset_index().rename(columns={'index':'customer type','Segment':'total customers'})
customer_segmentation
# Out:
#   customer type  total customers
# 0      Consumer             5191
# 1     Corporate             3020
# 2   Home Office             1783

# %%
plt.pie(customer_segmentation['total customers'],labels=customer_segmentation['customer type'],autopct='%1.1f%%')
plt.title('Distribution of customers')
plt.show()

# %%
sales_per_segment=df.groupby('Segment')['Sales'].sum().reset_index().rename(columns={'Segment':'customer type','Sales':'total Sales'})

# %%
sales_per_segment
# Out:
#   customer type   total Sales
# 0      Consumer  1.161401e+06
# 1     Corporate  7.061464e+05
# 2   Home Office  4.296531e+05

# %%
#bar chart
plt.bar(sales_per_segment['customer type'],sales_per_segment['total Sales'])
plt.title('sales per customer type')
plt.xlabel('Customer Type')
plt.ylabel('Total sales')
plt.show()

# %%
df['month']=df['Order Date'].dt.month

# %%
df['month']
# Out:
# 0       11
# 1       11
# 2        6
# 3       10
# 4       10
#         ..
# 9989     1
# 9990     2
# 9991     2
# 9992     2
# 9993     5
# Name: month, Length: 9994, dtype: int64

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2     CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2011-110422 2011-01-22 2011-01-24    Second Class    TB-21400
# 9990  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9993  CA-2014-119914 2014-05-05 2014-05-10    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df.query('Segment=="Consumer"').groupby('month')['Sales'].sum().plot(kind='bar',figsize=(6,6))
plt.title('consumer segment aggregated Mothly sales')
plt.show()

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2     CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2011-110422 2011-01-22 2011-01-24    Second Class    TB-21400
# 9990  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9993  CA-2014-119914 2014-05-05 2014-05-10    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
repeat_customers=df.groupby(['Customer ID','Customer Name','Segment'])['Order ID'].count().reset_index().rename(columns={'Order ID':'total orders'})

# %%
repeat_customers
# Out:
#     Customer ID       Customer Name    Segment  total orders
# 0      AA-10315          Alex Avila   Consumer            11
# 1      AA-10375        Allen Armold   Consumer            15
# 2      AA-10480        Andrew Allen   Consumer            12
# 3      AA-10645       Anna Andreadi   Consumer            18
# 4      AB-10015       Aaron Bergman   Consumer             6
# ..          ...                 ...        ...           ...
# 788    XP-21865        Xylona Preis   Consumer            28
# 789    YC-21895      Yoseph Carroll  Corporate             8
# 790    YS-21880       Yana Sorensen  Corporate            12
# 791    ZC-21910    Zuschuss Carroll   Consumer            31
# 792    ZD-21925  Zuschuss Donatelli   Consumer             9
#
# [793 rows x 4 columns]

# %%
repeat_customers['total orders'] >10
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 788     True
# 789    False
# 790     True
# 791     True
# 792    False
# Name: total orders, Length: 793, dtype: bool

# %%
top_customers=repeat_customers[repeat_customers['total orders'] >10]
top_customers
# Out:
#     Customer ID     Customer Name      Segment  total orders
# 0      AA-10315        Alex Avila     Consumer            11
# 1      AA-10375      Allen Armold     Consumer            15
# 2      AA-10480      Andrew Allen     Consumer            12
# 3      AA-10645     Anna Andreadi     Consumer            18
# 5      AB-10060   Adam Bellavance  Home Office            18
# ..          ...               ...          ...           ...
# 786    VW-21775   Victoria Wilson    Corporate            18
# 787    WB-21850     William Brown     Consumer            37
# 788    XP-21865      Xylona Preis     Consumer            28
# 790    YS-21880     Yana Sorensen    Corporate            12
# 791    ZC-21910  Zuschuss Carroll     Consumer            31
#
# [462 rows x 4 columns]

# %%
top_customers.sort_values(by='total orders',ascending=False)
# Out:
#     Customer ID        Customer Name      Segment  total orders
# 787    WB-21850        William Brown     Consumer            37
# 606    PP-18955           Paul Prost  Home Office            34
# 387    JL-15835             John Lee     Consumer            34
# 482    MA-17560         Matt Abelman  Home Office            34
# 147    CK-12205  Chloris Kastensmidt     Consumer            32
# ..          ...                  ...          ...           ...
# 479    LW-16990     Lindsay Williams    Corporate            11
# 413    KA-16525       Kelly Andreada     Consumer            11
# 411    JW-15955       Joni Wasserman     Consumer            11
# 406    JS-15685             Jim Sink    Corporate            11
# 0      AA-10315           Alex Avila     Consumer            11
#
# [462 rows x 4 columns]

# %% [markdown]
# # sales by customers

# %%
customers_sales=df.groupby(['Customer ID','Customer Name','Segment'])['Sales'].sum().reset_index()

# %%
customers_sales
# Out:
#     Customer ID       Customer Name    Segment     Sales
# 0      AA-10315          Alex Avila   Consumer  5563.560
# 1      AA-10375        Allen Armold   Consumer  1056.390
# 2      AA-10480        Andrew Allen   Consumer  1790.512
# 3      AA-10645       Anna Andreadi   Consumer  5086.935
# 4      AB-10015       Aaron Bergman   Consumer   886.156
# ..          ...                 ...        ...       ...
# 788    XP-21865        Xylona Preis   Consumer  2374.658
# 789    YC-21895      Yoseph Carroll  Corporate  5454.350
# 790    YS-21880       Yana Sorensen  Corporate  6720.444
# 791    ZC-21910    Zuschuss Carroll   Consumer  8025.707
# 792    ZD-21925  Zuschuss Donatelli   Consumer  1493.944
#
# [793 rows x 4 columns]

# %%
top_spenders=customers_sales.sort_values(by='Sales',ascending=False).head(5)

# %%
top_spenders
# Out:
#     Customer ID  Customer Name      Segment      Sales
# 700    SM-20320    Sean Miller  Home Office  25043.050
# 741    TC-20980   Tamara Chand    Corporate  19052.218
# 621    RB-19360   Raymond Buch     Consumer  15117.339
# 730    TA-21385   Tom Ashbrook  Home Office  14595.620
# 6      AB-10105  Adrian Barton     Consumer  14473.571

# %%
#repeat_customers=df.groupby(['Customer ID','Customer Name','Segment'])['Order ID'].sum().reset_index().rename(columns={'Order ID':'total orders'})

# %%
#repeat_customers

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2     CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2011-110422 2011-01-22 2011-01-24    Second Class    TB-21400
# 9990  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9993  CA-2014-119914 2014-05-05 2014-05-10    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %% [markdown]
# # Geographical analysis

# %% [markdown]
# # State

# %%
df['State'].value_counts().reset_index().rename(columns={'index':'State','State':'Number_of_customers'})
# Out:
#                    State  Number_of_customers
# 0             California                 2001
# 1               New York                 1128
# 2                  Texas                  985
# 3           Pennsylvania                  587
# 4             Washington                  506
# 5               Illinois                  492
# 6                   Ohio                  469
# 7                Florida                  383
# 8               Michigan                  255
# 9         North Carolina                  249
# 10               Arizona                  224
# 11              Virginia                  224
# 12               Georgia                  184
# 13             Tennessee                  183
# 14              Colorado                  182
# 15               Indiana                  149
# 16              Kentucky                  139
# 17         Massachusetts                  135
# 18            New Jersey                  130
# ...

# %%
state_sales=df.groupby('State')['Sales'].sum()

# %%
top_sales_per_state=state_sales.reset_index()

# %%
top_sales_per_state
# Out:
#                    State        Sales
# 0                Alabama   19510.6400
# 1                Arizona   35282.0010
# 2               Arkansas   11678.1300
# 3             California  457687.6315
# 4               Colorado   32108.1180
# 5            Connecticut   13384.3570
# 6               Delaware   27451.0690
# 7   District of Columbia    2865.0200
# 8                Florida   89473.7080
# 9                Georgia   49095.8400
# 10                 Idaho    4382.4860
# 11              Illinois   80166.1010
# 12               Indiana   53555.3600
# 13                  Iowa    4579.7600
# 14                Kansas    2914.3100
# 15              Kentucky   36591.7500
# 16             Louisiana    9217.0300
# 17                 Maine    1270.5300
# 18              Maryland   23705.5230
# 19         Massachusetts   28634.4340
# 20              Michigan   76269.6140
# 21             Minnesota   29863.1500
# 22           Mississippi   10771.3400
# 23              Missouri   22205.1500
# ...

# %%
top_sales_per_state.sort_values(by='Sales',ascending =False).head(10)
# Out:
#            State        Sales
# 3     California  457687.6315
# 30      New York  310876.2710
# 41         Texas  170188.0458
# 45    Washington  138641.2700
# 36  Pennsylvania  116511.9140
# 8        Florida   89473.7080
# 11      Illinois   80166.1010
# 33          Ohio   78258.1360
# 20      Michigan   76269.6140
# 44      Virginia   70636.7200

# %% [markdown]
# # City

# %%
df['City'].value_counts().reset_index().rename(columns={'index':'City','City':'Number_of_customers'})
# Out:
#                 City  Number_of_customers
# 0      New York City                  915
# 1        Los Angeles                  747
# 2       Philadelphia                  537
# 3      San Francisco                  510
# 4            Seattle                  428
# ..               ...                  ...
# 526         Glenview                    1
# 527    Missouri City                    1
# 528  Rochester Hills                    1
# 529         Palatine                    1
# 530        Manhattan                    1
#
# [531 rows x 2 columns]

# %%
City_sales=df.groupby('City')['Sales'].sum()
City_sales=City_sales.reset_index()

# %%
City_sales.sort_values(by='Sales',ascending=False).head(5)
# Out:
#               City       Sales
# 329  New York City  256368.161
# 266    Los Angeles  175851.341
# 452        Seattle  119540.742
# 438  San Francisco  112669.092
# 374   Philadelphia  109077.013

# %%
top_sales_per_state_city=df.groupby(['City','State'])['Sales'].sum().reset_index()

# %%
top_sales_per_state_city.sort_values(by='Sales',ascending=False).head(5)
# Out:
#               City         State       Sales
# 380  New York City      New York  256368.161
# 312    Los Angeles    California  175851.341
# 517        Seattle    Washington  119540.742
# 503  San Francisco    California  112669.092
# 430   Philadelphia  Pennsylvania  109077.013

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'total_discount',
#        'Dicounted_sales', 'selling_price', 'net profit per unit sold',
#        'order_delivery_time', 'net profit before discount', 'month'],
#       dtype='object')

# %% [markdown]
# # Category

# %%
products=df['Category'].unique()

# %%
products
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
len(df['Sub-Category'].unique())
# Out:
# 17

# %%
df.groupby('Category')['Sub-Category'].nunique().reset_index().sort_values(by='Sub-Category',ascending = False)
# Out:
#           Category  Sub-Category
# 1  Office Supplies             9
# 0        Furniture             4
# 2       Technology             4

# %%
category_sales=df.groupby('Category')['Sales'].sum().reset_index().sort_values(by='Sales',ascending = False)

# %%
category_sales
# Out:
#           Category        Sales
# 2       Technology  836154.0330
# 0        Furniture  741999.7953
# 1  Office Supplies  719047.0320

# %%
plt.pie(category_sales['Sales'],labels=category_sales['Category'],autopct='%1.1f%%')
plt.title('top product categories based on sales')
plt.show()

# %%
df.groupby('Sub-Category')['Sales'].sum().reset_index().sort_values(by='Sales',ascending= False)
# Out:
#    Sub-Category        Sales
# 13       Phones  330007.0540
# 5        Chairs  328449.1030
# 14      Storage  223843.6080
# 16       Tables  206965.5320
# 3       Binders  203412.7330
# 11     Machines  189238.6310
# 0   Accessories  167380.3180
# 6       Copiers  149528.0300
# 4     Bookcases  114879.9963
# 1    Appliances  107532.1610
# 9   Furnishings   91705.1640
# 12        Paper   78479.2060
# 15     Supplies   46673.5380
# 2           Art   27118.7920
# 7     Envelopes   16476.4020
# 10       Labels   12486.3120
# 8     Fasteners    3024.2800

# %%
df_sales=df.groupby(['Category','Sub-Category'])['Sales'].sum().reset_index().sort_values(by='Sales',ascending = False)

# %%
df_sales
# Out:
#            Category Sub-Category        Sales
# 16       Technology       Phones  330007.0540
# 1         Furniture       Chairs  328449.1030
# 11  Office Supplies      Storage  223843.6080
# 3         Furniture       Tables  206965.5320
# 6   Office Supplies      Binders  203412.7330
# 15       Technology     Machines  189238.6310
# 13       Technology  Accessories  167380.3180
# 14       Technology      Copiers  149528.0300
# 0         Furniture    Bookcases  114879.9963
# 4   Office Supplies   Appliances  107532.1610
# 2         Furniture  Furnishings   91705.1640
# 10  Office Supplies        Paper   78479.2060
# 12  Office Supplies     Supplies   46673.5380
# 5   Office Supplies          Art   27118.7920
# 7   Office Supplies    Envelopes   16476.4020
# 9   Office Supplies       Labels   12486.3120
# 8   Office Supplies    Fasteners    3024.2800

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='Sales',y='Sub-Category',data=df_sales,hue='Category')
plt.title('top sales per sub category')
plt.show()

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'total_discount',
#        'Dicounted_sales', 'selling_price', 'net profit per unit sold',
#        'order_delivery_time', 'net profit before discount', 'month'],
#       dtype='object')

# %%
df[df['Sub-Category']=='Phones'].groupby('Product Name')['Profit'].sum().sort_values(ascending= False)
# Out:
# Product Name
# Samsung Galaxy Mega 6.3                                                                                 1822.7566
# Apple iPhone 5                                                                                          1611.5784
# Panasonic KX-TG9471B                                                                                    1168.1004
# Panasonic KX-TG9541B DECT 6.0 Digital 2-Line Expandable Cordless Phone With Digital Answering System    1147.4235
# Samsung Galaxy S4 Mini                                                                                  1104.4765
#                                                                                                           ...
# Cisco IP Phone 7961G-GE VoIP phone                                                                      -119.1190
# Samsung Galaxy Note 2                                                                                   -128.7972
# ...

# %%
df[df['Sub-Category']=='Machines'].groupby('Product Name')['Profit'].sum().sort_values(ascending= False)
# Out:
# Product Name
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                4094.9766
# Ativa V4110MDD Micro-Cut Shredder                                        3772.9461
# 3D Systems Cube Printer, 2nd Generation, Magenta                         3717.9714
# Zebra ZM400 Thermal Label Printer                                        3343.5360
# Canon imageCLASS MF7460 Monochrome Digital Laser Multifunction Copier    1995.9900
#                                                                            ...
# Epson TM-T88V Direct Thermal Printer - Monochrome - Desktop             -1057.2300
# Cisco TelePresence System EX90 Videoconferencing Unit                   -1811.0784
# Cubify CubeX 3D Printer Triple Head Print                               -3839.9904
# Lexmark MX611dhe Monochrome Laser Printer                               -4589.9730
# Cubify CubeX 3D Printer Double Head Print                               -8879.9704
# Name: Profit, Length: 63, dtype: float64

# %% [markdown]
# # Region

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
region_sales=df.groupby(['Region','Sub-Category'])['Sales'].sum().reset_index().sort_values(by='Sales',ascending = False)

# %%
region_sales
# Out:
#      Region Sub-Category       Sales
# 56     West       Chairs  101781.328
# 30     East       Phones  100614.982
# 64     West       Phones   98684.352
# 22     East       Chairs   96260.683
# 5   Central       Chairs   85230.646
# ..      ...          ...         ...
# 44    South       Labels    2353.180
# 59     West    Fasteners     923.216
# 25     East    Fasteners     819.718
# 8   Central    Fasteners     778.030
# 42    South    Fasteners     503.316
#
# [68 rows x 3 columns]

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Sub-Category',y='Sales',data=region_sales,hue='Region')
plt.title('Sales per Sub Category (by region)')
plt.xticks(rotation=45)
plt.show()

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'total_discount',
#        'Dicounted_sales', 'selling_price', 'net profit per unit sold',
#        'order_delivery_time', 'net profit before discount', 'month'],
#       dtype='object')

# %% [markdown]
# # Discount

# %%
plt.hist(x='Discount',data=df)
plt.title('Distribution of Discount')
plt.xlabel('Discount')
plt.ylabel('Count')
plt.show()

# %%
df['year']=df['Order Date'].dt.year

# %%
df['year']
# Out:
# 0       2013
# 1       2013
# 2       2013
# 3       2012
# 4       2012
#         ...
# 9989    2011
# 9990    2014
# 9991    2014
# 9992    2014
# 9993    2014
# Name: year, Length: 9994, dtype: int64

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'total_discount',
#        'Dicounted_sales', 'selling_price', 'net profit per unit sold',
#        'order_delivery_time', 'net profit before discount', 'month', 'year'],
#       dtype='object')

# %%
Dicounted_year_sales=df.groupby('year')['Dicounted_sales'].sum().reset_index().sort_values(by='Dicounted_sales',ascending = False)

# %%
Dicounted_year_sales
# Out:
#    year  Dicounted_sales
# 3  2014    632548.810866
# 2  2013    527707.888720
# 1  2012    407671.323660
# 0  2011    406690.702713

# %%
plt.bar(Dicounted_year_sales['year'],Dicounted_year_sales['Dicounted_sales'])
plt.title('Dicounted Yearly sales')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.show()

# %%
sns.lineplot(x=Dicounted_year_sales['year'],y=Dicounted_year_sales['Dicounted_sales'],data=Dicounted_year_sales,marker='o',linestyle='--')
plt.title('Total Dicounted_year_sales')
plt.show()

# %%
year_sales=df.groupby('year')['Sales'].sum().reset_index()

# %%
year_sales
# Out:
#    year        Sales
# 0  2011  484247.4981
# 1  2012  470532.5090
# 2  2013  608473.8300
# 3  2014  733947.0232

# %%
sns.lineplot(x=year_sales['year'],y=year_sales['Sales'],data =year_sales,marker='o',linestyle='--')
plt.title('total sales by year')
plt.show()

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'total_discount',
#        'Dicounted_sales', 'selling_price', 'net profit per unit sold',
#        'order_delivery_time', 'net profit before discount', 'month', 'year'],
#       dtype='object')

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2     CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2011-110422 2011-01-22 2011-01-24    Second Class    TB-21400
# 9990  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9993  CA-2014-119914 2014-05-05 2014-05-10    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df['Order Date'].dt.year==2013
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Name: Order Date, Length: 9994, dtype: bool

# %%
year_sales_2013 = df[df['Order Date'].dt.year==2013]

# %%
year_sales_2013
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1     CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2     CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 13    CA-2013-161389 2013-12-06 2013-12-11  Standard Class    IM-15070
# 21    CA-2013-137330 2013-12-10 2013-12-14  Standard Class    KB-16585
# ...              ...        ...        ...             ...         ...
# 9978  US-2013-103674 2013-12-07 2013-12-11  Standard Class    AP-10720
# 9979  US-2013-103674 2013-12-07 2013-12-11  Standard Class    AP-10720
# 9982  US-2013-157728 2013-09-23 2013-09-29  Standard Class    RC-19960
# 9983  US-2013-157728 2013-09-23 2013-09-29  Standard Class    RC-19960
# 9986  CA-2013-125794 2013-09-30 2013-10-04  Standard Class    ML-17410
#
#         Customer Name      Segment        Country          City       State  \
# ...

# %%
Quartile_sales=year_sales_2013.resample('Q', on='Order Date')['Sales'].sum().reset_index().rename(columns={'Order Date':'Quartile','Sales':'total sales'})

# %%
Quartile_sales
# Out:
#     Quartile  total sales
# 0 2013-03-31   92596.4190
# 1 2013-06-30  135370.1130
# 2 2013-09-30  144614.4282
# 3 2013-12-31  235892.8698

# %%
sns.lineplot(x=Quartile_sales['Quartile'],y=Quartile_sales['total sales'],data =Quartile_sales,marker='o',linestyle='--')
plt.title('total sales by year')
plt.xticks(rotation=70)
plt.show()

# %%
Monthly_sales=year_sales_2013.resample('M', on='Order Date')['Sales'].sum().reset_index().rename(columns={'Order Date':'Month','Sales':'total sales'})

# %%
Monthly_sales.sort_values(by='total sales',ascending=False)
# Out:
#         Month  total sales
# 11 2013-12-31   97237.4170
# 10 2013-11-30   82192.3228
# 8  2013-09-30   72908.1089
# 4  2013-05-31   56691.0770
# 9  2013-10-31   56463.1300
# 2  2013-03-31   51186.2170
# 5  2013-06-30   39430.4430
# 3  2013-04-30   39248.5930
# 6  2013-07-31   38440.7550
# 7  2013-08-31   33265.5643
# 1  2013-02-28   22867.7110
# 0  2013-01-31   18542.4910

# %%
sns.lineplot(x=Monthly_sales['Month'],y=Monthly_sales['total sales'],data =Monthly_sales,marker='o',linestyle='--')
plt.title('total sales by month over 2013')
plt.xticks(rotation=70)
plt.show()

# %%
#df['month']=df['Order Date'].dt.month

# %%
df.groupby('month')['Sales'].sum()
# Out:
# month
# 1      95365.9376
# 2      60172.6494
# 3     199252.9840
# 4     141851.5674
# 5     156122.2867
# 6     147082.6113
# 7     149580.8380
# 8     159589.4510
# 9     309770.0997
# 10    197115.2017
# 11    349120.0740
# 12    332177.1595
# Name: Sales, dtype: float64

# %%
df.groupby('month')['Sales'].sum().plot(marker='o')     
plt.title('Mothly Sales')
plt.ylabel('Sales')
plt.show()

# %%
quarter_sales=df.groupby(df['Order Date'].dt.to_period('Q'))['Sales'].sum()

# %%
quarter_sales                      #year=['2011Q1',......,2014Q4]
# Out:
# Order Date
# 2011Q1     74447.7960
# 2011Q2     86538.7596
# 2011Q3    143633.2123
# 2011Q4    179627.7302
# 2012Q1     68851.7386
# 2012Q2     89124.1870
# 2012Q3    130259.5752
# 2012Q4    182297.0082
# 2013Q1     92596.4190
# 2013Q2    135370.1130
# 2013Q3    144614.4282
# 2013Q4    235892.8698
# 2014Q1    118895.6174
# 2014Q2    134023.4058
# 2014Q3    200433.1730
# 2014Q4    280594.8270
# Freq: Q-DEC, Name: Sales, dtype: float64

# %%
type(quarter_sales.index)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %%
plt.plot(quarter_sales.index.astype(str),quarter_sales.values,marker='o')
plt.title('Quarter Sales Trend')
plt.xticks(rotation=70)
plt.show()

# %%
Region_sales=df.groupby(['Region','year'])['Sales'].sum().reset_index()

# %%
Region_sales
# Out:
#      Region  year        Sales
# 0   Central  2011  103838.1646
# 1   Central  2012  102874.2220
# 2   Central  2013  147429.3760
# 3   Central  2014  147098.1282
# 4      East  2011  128680.4570
# 5      East  2012  156332.0570
# 6      East  2013  180529.3100
# 7      East  2014  213239.4160
# 8     South  2011  103845.8435
# 9     South  2012   71359.9805
# 10    South  2013   93539.1275
# 11    South  2014  122976.9535
# 12     West  2011  147883.0330
# 13     West  2012  139966.2495
# 14     West  2013  186976.0165
# 15     West  2014  250632.5255

# %%
sns.barplot(x='Region',y='Sales',data=Region_sales,hue='year')
plt.title('Yearly Sales per Region over the years')
plt.show()

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'total_discount',
#        'Dicounted_sales', 'selling_price', 'net profit per unit sold',
#        'order_delivery_time', 'net profit before discount', 'month', 'year'],
#       dtype='object')

# %% [markdown]
# # Profit

# %%
df.groupby('year')['Profit'].sum().reset_index().sort_values(by='Profit',ascending = False)
# Out:
#    year      Profit
# 3  2014  93507.5131
# 2  2013  81726.9308
# 1  2012  61618.6037
# 0  2011  49543.9741

# %%
df.groupby('month')['Profit'].sum().reset_index().sort_values(by='Profit',ascending = False)
# Out:
#     month      Profit
# 11     12  43436.1339
# 8       9  37293.1925
# 10     11  35825.5366
# 9      10  31469.6638
# 2       3  26806.5737
# 4       5  22308.5128
# 7       8  21896.7154
# 5       6  20899.3345
# 6       7  13535.3830
# 3       4  13437.8068
# 1       2  10288.8987
# 0       1   9199.2700

# %%
df.groupby(['year','month'])['Profit'].sum().reset_index().sort_values(by='Profit',ascending = False)
# Out:
#     year  month      Profit
# 35  2013     12  17902.7301
# 33  2013     10  15763.3797
# 38  2014      3  12957.8999
# 22  2012     11  12474.7884
# 44  2014      9  11395.4394
# 14  2012      3   9724.6724
# 46  2014     11   9682.5519
# 45  2014     10   9440.6608
# 32  2013      9   9360.4910
# 10  2011     11   9292.1269
# 11  2011     12   8983.5699
# 43  2014      8   8894.4486
# 28  2013      5   8627.4764
# 47  2014     12   8532.8680
# 8   2011      9   8328.0994
# 20  2012      9   8209.1627
# 41  2014      6   8087.6684
# 23  2012     12   8016.9659
# 36  2014      1   7208.6826
# 42  2014      7   6623.5571
# 40  2014      5   6274.4578
# 19  2012      8   5355.8084
# 7   2011      8   5318.1050
# 25  2013      2   4996.2467
# 5   2011      6   4976.5244
# 16  2012      5   4667.8690
# 29  2013      6   4499.5845
# 30  2013      7   4464.6602
# 34  2013     11   4376.0694
# 15  2012      4   4187.4962
# 26  2013      3   3625.2715
# 3   2011      4   3488.8352
# ...

# %% [markdown]
# # Profit by segment

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
segment_profit =df.groupby('Segment')['Profit'].sum().reset_index().sort_values(by='Profit',ascending = False)

# %%
segment_profit
# Out:
#        Segment       Profit
# 0     Consumer  134119.2092
# 1    Corporate   91979.1340
# 2  Home Office   60298.6785

# %%
plt.pie(segment_profit['Profit'],labels=segment_profit['Segment'],autopct='%1.1f%%')
plt.title('Profit by Segment')
plt.show()

# %% [markdown]
# # Profit by Category

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
Category_profit =df.groupby('Category')['Profit'].sum().reset_index().sort_values(by='Profit',ascending = False)

# %%
Category_profit
# Out:
#           Category       Profit
# 2       Technology  145454.9481
# 1  Office Supplies  122490.8008
# 0        Furniture   18451.2728

# %%
df['Category']=='Technology'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991     True
# 9992    False
# 9993    False
# Name: Category, Length: 9994, dtype: bool

# %%
df[df['Category']=='Technology']
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 7     CA-2011-115812 2011-06-09 2011-06-14  Standard Class    BH-11710
# 11    CA-2011-115812 2011-06-09 2011-06-14  Standard Class    BH-11710
# 19    CA-2011-143336 2011-08-27 2011-09-01    Second Class    ZD-21925
# 26    CA-2013-121755 2013-01-16 2013-01-20    Second Class    EH-13945
# 35    CA-2013-117590 2013-12-09 2013-12-11     First Class    GH-14485
# ...              ...        ...        ...             ...         ...
# 9983  US-2013-157728 2013-09-23 2013-09-29  Standard Class    RC-19960
# 9986  CA-2013-125794 2013-09-30 2013-10-04  Standard Class    ML-17410
# 9987  CA-2014-163629 2014-11-18 2014-11-22  Standard Class    RA-19885
# 9988  CA-2014-163629 2014-11-18 2014-11-22  Standard Class    RA-19885
# 9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
#
#            Customer Name    Segment        Country           City       State  \
# ...

# %%
df[df['Category']=='Technology'].groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False)
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Machines        3384.7569
# Name: Profit, dtype: float64

# %%
df['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df[df['Sub-Category']=='Copiers']
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 335   CA-2012-137946 2012-09-01 2012-09-04    Second Class    DB-13615
# 392   US-2011-135972 2011-09-21 2011-09-23    Second Class    JG-15115
# 406   CA-2014-117457 2014-12-09 2014-12-13  Standard Class    KH-16510
# 515   CA-2014-127432 2014-01-23 2014-01-28  Standard Class    AD-10180
# 595   CA-2011-131450 2011-08-08 2011-08-15  Standard Class    LR-16915
# ...              ...        ...        ...             ...         ...
# 8820  CA-2014-100622 2014-11-04 2014-11-08  Standard Class    DK-13090
# 8990  US-2012-128587 2012-12-24 2012-12-30  Standard Class    HM-14860
# 9617  CA-2014-160633 2014-11-17 2014-11-22  Standard Class    BS-11380
# 9839  US-2013-125402 2013-09-26 2013-10-02  Standard Class    DL-12865
# 9929  CA-2013-129630 2013-09-05 2013-09-05        Same Day    IM-15055
#
#        Customer Name      Segment        Country           City       State  \
# ...

# %%
df[df['Sub-Category']=='Copiers'].groupby('Product Name')['Profit'].sum().sort_values(ascending=False)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                   25199.9280
# Hewlett Packard LaserJet 3310 Copier                     6983.8836
# Canon PC1060 Personal Laser Copier                       4570.9347
# Hewlett Packard 610 Color Digital Copier / Printer       3124.9375
# Canon Imageclass D680 Copier / Fax                       2799.9600
# Canon PC940 Copier                                       2092.4535
# Sharp AL-1530CS Digital Copier                           2064.9587
# Canon PC1080F Personal Copier                            1973.9671
# Canon Image Class D660 Copier                            1691.9718
# Sharp 1540cs Digital Laser Copier                        1649.9700
# Canon PC-428 Personal Copier                             1469.9265
# Brother DCP1000 Digital 3 in 1 Multifunction Machine     1154.9615
# Hewlett Packard 310 Color Digital Copier                  839.9720
# Name: Profit, dtype: float64

# %%
df.groupby(['year','Category'])['Sales'].sum()
# Out:
# year  Category
# 2011  Furniture          157192.8531
#       Office Supplies    151776.4120
#       Technology         175278.2330
# 2012  Furniture          170518.2370
#       Office Supplies    137233.4630
#       Technology         162780.8090
# 2013  Furniture          198901.4360
#       Office Supplies    183510.5900
#       Technology         226061.8040
# 2014  Furniture          215387.2692
#       Office Supplies    246526.5670
#       Technology         272033.1870
# Name: Sales, dtype: float64

# %%
sales_group=df.groupby(['year','Category'])['Sales'].sum().unstack()

# %%
sales_group
# Out:
# Category    Furniture  Office Supplies  Technology
# year
# 2011      157192.8531       151776.412  175278.233
# 2012      170518.2370       137233.463  162780.809
# 2013      198901.4360       183510.590  226061.804
# 2014      215387.2692       246526.567  272033.187

# %%
profit_group=df.groupby(['year','Category'])['Profit'].sum().unstack()

# %%
profit_group
# Out:
# Category  Furniture  Office Supplies  Technology
# year
# 2011      5457.7255       22593.4161  21492.8325
# 2012      3015.2029       25099.5338  33503.8670
# 2013      6959.9531       35015.6639  39751.3138
# 2014      3018.3913       39782.1870  50706.9348

# %%
sales_group.plot(kind='bar')
plt.xlabel('Year')
plt.ylabel('Total sales')
plt.title('total sales by category over years')
plt.show()

# %%
profit_group.plot(kind='bar')
plt.xlabel('Year')
plt.ylabel('Total profit')
plt.title('total profit by category over years')
plt.show()

# %%
ax1=sales_group.plot(kind='bar')
plt.xlabel('Year')
plt.ylabel('Total sales')
plt.title('total sales by category over years')
plt.show()

ax2=profit_group.plot(kind='bar')
plt.xlabel('Year')
plt.ylabel('Total profit')
plt.title('total profit by category over years')
plt.show()

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'total_discount',
#        'Dicounted_sales', 'selling_price', 'net profit per unit sold',
#        'order_delivery_time', 'net profit before discount', 'month', 'year'],
#       dtype='object')

# %% [markdown]
# # order_delivery_time

# %%
df['order_delivery_time'].describe()
# Out:
# count                         9994
# mean     3 days 23:00:46.828096858
# std      1 days 17:55:49.143486104
# min                0 days 00:00:00
# 25%                3 days 00:00:00
# 50%                4 days 00:00:00
# 75%                5 days 00:00:00
# max                7 days 00:00:00
# Name: order_delivery_time, dtype: object

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df['Ship Mode']=='Standard Class'
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 9989    False
# 9990     True
# 9991     True
# 9992     True
# 9993    False
# Name: Ship Mode, Length: 9994, dtype: bool

# %%
df[df['Ship Mode']=='Standard Class']
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4     US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 5     CA-2011-115812 2011-06-09 2011-06-14  Standard Class    BH-11710
# 6     CA-2011-115812 2011-06-09 2011-06-14  Standard Class    BH-11710
# 7     CA-2011-115812 2011-06-09 2011-06-14  Standard Class    BH-11710
# ...              ...        ...        ...             ...         ...
# 9987  CA-2014-163629 2014-11-18 2014-11-22  Standard Class    RA-19885
# 9988  CA-2014-163629 2014-11-18 2014-11-22  Standard Class    RA-19885
# 9990  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
# 9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class    DB-13060
#
#         Customer Name    Segment        Country             City       State  \
# ...

# %%
df[df['Ship Mode']=='Standard Class']['order_delivery_time'].mean()
# Out:
# Timedelta('5 days 00:10:22.520107238')

# %%
df[df['Ship Mode']=='Second Class']['order_delivery_time'].mean()
# Out:
# Timedelta('3 days 05:45:44.884318766')

# %%
df[df['Ship Mode']=='First Class']['order_delivery_time'].mean()
# Out:
# Timedelta('2 days 04:22:09.518855656')

# %%
df[df['Ship Mode']=='Same Day']['order_delivery_time'].mean()
# Out:
# Timedelta('0 days 01:03:38.784530386')

# %%
shipment_delivery =df.groupby('Ship Mode')['order_delivery_time'].mean().reset_index()

# %%
shipment_delivery
# Out:
#         Ship Mode       order_delivery_time
# 0     First Class 2 days 04:22:09.518855656
# 1        Same Day 0 days 01:03:38.784530386
# 2    Second Class 3 days 05:45:44.884318766
# 3  Standard Class 5 days 00:10:22.520107238

# %%
plt.bar(shipment_delivery['Ship Mode'],shipment_delivery['order_delivery_time'])
plt.title('Ship Mode & Delivery Time')
plt.show()
